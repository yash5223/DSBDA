# %%
import pandas as pd

# %%
df=pd.read_csv('HousingData.csv')

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
df.head(2)
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                  2.5         3650
# 1  6762810635  42491                   4                  2.5         2920
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# 0                       5  ...        1921                0       122003
# 1                       5  ...        1909                0       122004
#
#    Lattitude  Longitude  living_area_renov  lot_area_renov  \
# 0    52.8645   -114.557               2880            5400
# 1    52.8878   -114.470               2470            4000
#
#    Number of schools nearby  Distance from the airport    Price
# 0                         2                         58  2380000
# ...

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
X = data[ [ "RM" ] ]
Y = data[ [ "MEDV" ] ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 X = data[ [ "RM" ] ]
#       2 Y = data[ [ "MEDV" ] ]
#
# NameError: name 'data' is not defined

# %%
from seaborn import scatterplot
scatterplot(x = X.RM, y = Y.MEDV)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5756\594005855.py in ?()
#       1 from seaborn import scatterplot
# ----> 2 scatterplot(x = X.RM, y = Y.MEDV)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'RM'

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
model = lm.fit(xtrain, ytrain)

# %%
b1 = model.coef_

# %%
b0 = model.intercept_

# %%
b0
# Out:
# np.float64(63810.68867953884)

# %%
b1
# Out:
# array([-55542.51089538,    982.4782508 ,    315.35496658])

# %%
from seaborn import regplot
regplot(x = xtrain.RM, y = ytrain.MEDV)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5756\4158879627.py in ?()
#       1 from seaborn import regplot
# ----> 2 regplot(x = xtrain.RM, y = ytrain.MEDV)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'RM'

# %%
# Predict
pred = model.predict(xtest)

# Evaluate the model
from sklearn.metrics import mean_absolute_error, mean_squared_error

mae = mean_absolute_error(ytest, pred)
mse = mean_squared_error(ytest, pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)

# Conclusion
print("\nAs per the result, our model is not very good for predicting housing prices.")
print("One can improve the prediction using other ML algorithms and techniques.")

# Print actual values
print("\nActual MEDV values:\n")
print(ytest)
# Out:
# Mean Absolute Error: 165988.51192638464
# Mean Squared Error: 64556795557.111404
#
# As per the result, our model is not very good for predicting housing prices.
# One can improve the prediction using other ML algorithms and techniques.
#
# Actual MEDV values:
#
# 7874     699000
# 5142     322500
# 11584    389500
# 9623     210500
# 6153     183000
#           ...
# 13923    180000
# 7021     485000
# 11977    985000
# 11860    380950
# 13385    437500
# Name: Price, Length: 2924, dtype: int64
